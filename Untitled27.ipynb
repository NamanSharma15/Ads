# %% [markdown]
# <a href="https://colab.research.google.com/github/Ns1501/Ads/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ADS Assignment - Plotting

# %% [markdown]
# ### Naman Sharma 220335
# ### Sarthak Gupta 220326
# ### Ratul Pal 220325

# %% [markdown]
# ### Importing Librares

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cufflinks as cf
import numpy as np
import plotly

# %% [markdown]
# ### Reading the CSV file

# %%
df  = pd.read_csv('abc.csv')

# %% [markdown]
# ### Univariate plotting

# %%
df["Average Benefit Per Person"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Average Benefit Per Person"].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### . Bivariate plotting

# %%
df.plot(x='Average Participation', y='Average Benefit Per Person', kind='scatter')
# Out:
# <Axes: xlabel='Average Participation', ylabel='Average Benefit Per Person'>

# %%
df.plot(x='Average Participation', y='Average Benefit Per Person', kind='line')
# Out:
# <Axes: xlabel='Average Participation'>

# %% [markdown]
# ### Multivariate plotting

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

def func(x, y):
   return 2* x + 6* y - 10
y = pd.Series([int(i.replace(",","")) for i  in df["Average Participation"]])
x = df["Average Benefit Per Person"].to_numpy()

z = func(x, y)

fig, ax = plt.subplots()

s = ax.scatter(x, y, c=z, s=100, marker='*', cmap='plasma')

fig.colorbar(s)

# %% [markdown]
# ### Interactive plot with Plotly and cufflinks

# %%
import plotly.graph_objects as go
fig = go.Figure(
    data=[go.Bar(y=df["Average Participation"])],
    layout_title_text="Interactive graph with Plotly"
)
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Geographical plotting with choropleth maps.

# %%
import plotly.express as px

df = px.data.election()
geojson = px.data.election_geojson()

fig = px.choropleth(df, geojson=geojson, color="Bergeron",
                    locations="district", featureidkey="properties.district",
                    projection="mercator"
                   )
fig.update_geos(fitbounds="locations", visible=False)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
print("Election Choropleth Graph")
fig.show(renderer="colab")
# Out:
# Election Choropleth Graph
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
